# %%
import os
import glob
import pandas as pd
import numpy as np 
import pingouin as pg 
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor

warnings.filterwarnings("ignore")

# %%
curr_dir = os.getcwd()
avg_dir = curr_dir +"/AVG" 

rating_data = pd.read_csv( avg_dir + "/Dynamic_Rating.csv", index_col=0).values
rating_data.shape
# Out:
# (52, 16)

# %%
data_list = os.listdir(avg_dir)
data_list = sorted([ data for data in data_list if not data.startswith(".") and data != 'Dynamic_Rating.csv' and not data.endswith(".npy")])

avg_data = { str(x).split(sep=".")[0] : pd.read_csv(f"{avg_dir}/{x}", index_col=0).values for x in data_list}

avg_arr = [ ]

for ind, x in avg_data.items() : 
    #avg_arr.append(x.mean(axis=0)) # 16개 영상별로 평균을 내는 경우
    avg_arr.append(x.mean(axis=1)) # 52명 데이터를 평균내는 경우
    #avg_arr.append(x.flatten())

avg_arr = np.array(avg_arr).T

for key in avg_data.keys() : 
    print (key)
    print(avg_data[key].shape)
    print("-"*20)

print(avg_arr.shape)
# Out:
# Blinking
# (52, 16)
# --------------------
# Fixation_Duration
# (52, 16)
# --------------------
# Fixation_Num
# (52, 16)
# --------------------
# Saccade_Duration
# (52, 16)
# --------------------
# left_iris
# (52, 16)
# --------------------
# left_pupil
# (52, 16)
# --------------------
# right_iris
# (52, 16)
# --------------------
# right_pupil
# (52, 16)
# --------------------
# (52, 8)

# %%
rating_data.shape
# Out:
# (52, 16)

# %%
# Block별 데이터 

data_list = os.listdir(avg_dir)
data_list = sorted([ data for data in data_list if not data.startswith(".") and data != 'Dynamic_Rating.csv' and not data.endswith(".npy")])

#block_rating = rating_data.reshape(len(rating_data),-1,4).mean(axis=0).T # 16개 영상별로 평균을 내는 경우
block_rating = rating_data.reshape(len(rating_data),-1,4).mean(axis=1).T # 52명 데이터를 평균내는 경우

avg_data = { str(x).split(sep=".")[0] : pd.read_csv(f"{avg_dir}/{x}", index_col=0).values for x in data_list}

block_arr = [ ]
for key, value in avg_data.items() : 
    #block_arr.append(value.reshape(len(value),-1,4).mean(axis=0)) # 16개 영상별로 평균을 내는 경우 -> (video num, Block num, Eye factors)
    block_arr.append(value.reshape(len(value),-1,4).mean(axis=1)) # 52명 데이터를 평균내는 경우

block_arr = np.array(block_arr).T
print(block_arr.shape) 
print("-"*20,"\n")
# Out:
# (4, 52, 8)
# --------------------

# %%
# SSQ 데이터 
items = ['Bleary' , 'Dry_Eyed' , 'Eyestrain', 'Gritty', 'Eye_Ache', 'Sting', \
        'Heavy_Eyes', 'Hazy', 'Warm_Eyes', 'Flickering', 'Watery_Eyes', 'Feeling_heavy_in_the_head', 'Feel_heavy', \
        'Difficulty_concentrating', 'Dizzy', 'Stiff_shoulder', 'Stiff_neck', 'Sleepy', 'Vomiiting', 'Vertigo', 'Nausea', \
        'Difficulty_focussing', 'Double_vision', 'Near_vision_difficulty', \
        'Far_vision_difficulty', 'Pain_in_the_temple', 'Pain_in_the_middle_of_the_head', 'Pain_in_the_back_of_the_head' ]

ssq_arr = np.load(avg_dir+"/ssq.npy")

ssq_arr = ssq_arr[..., 1:]

ssq_arr.shape
# Out:
# (28, 52, 4)

# %%
# Dynamic ratign DF

#arr = np.concatenate([avg_arr, rating_data.mean(axis=0).reshape(-1,1)], axis=1) # 16개 영상별로 평균을 내는 경우
arr = np.concatenate([avg_arr, rating_data.mean(axis=1).reshape(-1,1)], axis=1) # 52명 데이터를 평균내는 경우
#arr = np.concatenate([avg_arr, rating_data.flatten().reshape(-1,1)], axis=1)

print( "arr shape : ", arr.shape)

names = list(avg_data.keys())
names.append('DynamicRating')

#df = pd.DataFrame(arr, columns= names )# 16개 영상별로 평균을 내는 경우
df = pd.DataFrame(np.concatenate([avg_arr, rating_data.mean(axis=1).reshape(-1,1)], axis=1 ), columns= names )# 52명 데이터를 평균내는 경우
#df = pd.DataFrame(arr, columns=names)

print("Dataframe shape :",df.shape)
# Out:
# arr shape :  (52, 9)
# Dataframe shape : (52, 9)

# %%
# Dynamic ratign DF Min_Max scaling 

def min_max_scaler( series) :
    min = series.min()
    max = series.max()
    x = (series - min ) / ( max - min ) 
    return x 

#df = df.apply( min_max_scaler)

# %%
VIF             = pd.DataFrame()
VIF['VIF']      = [variance_inflation_factor(df.iloc[:,:-1].values, i) for i in range(df.iloc[:,:-1].shape[1])]
VIF['Variable'] = df.iloc[:,:-1].columns

VIF
# Out:
#           VIF           Variable
# 0   13.280531           Blinking
# 1   94.530617  Fixation_Duration
# 2  173.752270       Fixation_Num
# 3    7.707274   Saccade_Duration
# 4  158.025092          left_iris
# 5  771.283009         left_pupil
# 6  200.045989         right_iris
# 7  930.124524        right_pupil

# %%
df_vif = df[['Blinking','Fixation_Duration','Fixation_Num','Saccade_Duration']]
VIF             = pd.DataFrame()
VIF['VIF']      = [variance_inflation_factor(df_vif.values, i) for i in range(df_vif.shape[1])]
VIF['Variable'] = df_vif.columns

VIF
# Out:
#          VIF           Variable
# 0   7.254987           Blinking
# 1  12.996583  Fixation_Duration
# 2  26.738414       Fixation_Num
# 3   6.022749   Saccade_Duration

# %%
# "DynamicRating ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil"

m = ols("DynamicRating ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil", data=df).fit()
print(f"R vlaue : {np.sqrt(m.rsquared):.4f} || ANOVA p-value : {m.f_pvalue:.2f}")
print(m.summary())
# Out:
# R vlaue : 0.4920 || ANOVA p-value : 0.12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     1.717
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):              0.122
# Time:                        14:25:33   Log-Likelihood:                -54.722
# No. Observations:                  52   AIC:                             127.4
# Df Residuals:                      43   BIC:                             145.0
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -16.6315      8.187     -2.031      0.048     -33.143      -0.121
# Blinking              0.0154      0.007      2.310      0.026       0.002       0.029
# Fixation_Duration     0.0210      0.009      2.238      0.030       0.002       0.040
# Fixation_Num          0.0264      0.012      2.124      0.039       0.001       0.052
# Saccade_Duration      0.0348      0.015      2.380      0.022       0.005       0.064
# left_iris            -0.0137      0.381     -0.036      0.971      -0.781       0.754
# right_iris            0.6791      0.486      1.396      0.170      -0.302       1.660
# left_pupil           -0.6568      0.635     -1.035      0.307      -1.937       0.623
# right_pupil           0.7607      0.702      1.084      0.284      -0.654       2.176
# ==============================================================================
# Omnibus:                        0.809   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.667   Jarque-Bera (JB):                0.897
# Skew:                          -0.256   Prob(JB):                        0.639
# Kurtosis:                       2.612   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
m = ols("DynamicRating ~ Blinking ", data=df).fit()
 
print(f"R vlaue : {np.sqrt(m.rsquared):.4f} || ANOVA p-value : {m.f_pvalue:.2f}")

print(m.summary())
# Out:
# R vlaue : 0.3143 || ANOVA p-value : 0.02
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     5.479
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0233
# Time:                        01:56:38   Log-Likelihood:                -59.225
# No. Observations:                  52   AIC:                             122.5
# Df Residuals:                      50   BIC:                             126.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2800      0.284     11.532      0.000       2.709       3.851
# Blinking       0.0113      0.005      2.341      0.023       0.002       0.021
# ==============================================================================
# Omnibus:                        1.547   Durbin-Watson:                   1.683
# Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.486
# Skew:                          -0.313   Prob(JB):                        0.476
# Kurtosis:                       2.459   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Block별 Dynamic rating LR
Blocks = ['HMHB', 'HMLB', "LMHB", "LMLB"]
for ind, value in enumerate(block_arr):
    block_df = pd.DataFrame(np.concatenate([value, block_rating[ind].reshape(-1,1)], axis=1 ), columns=names)
    #block_df.apply(min_max_scaler)
    #block_df.to_csv(f"./DR-{Blocks[ind]}.csv")
    #m = ols("DynamicRating ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil", data=block_df).fit()
    m = ols("DynamicRating ~ Blinking", data=block_df).fit()
    print(Blocks[ind])
    #print(f"R2 vlaue : {m.rsquared:.4f} || ANOVA p-value : {m.f_pvalue:.2f}")
    print(m.summary())
    print("="*100)
    print( "\n")
# Out:
# HMHB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     2.818
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0994
# Time:                        01:56:38   Log-Likelihood:                -60.123
# No. Observations:                  52   AIC:                             124.2
# Df Residuals:                      50   BIC:                             128.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5005      0.284     12.332      0.000       2.930       4.071
# Blinking       0.0080      0.005      1.679      0.099      -0.002       0.018
# ==============================================================================
# Omnibus:                        3.112   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.211   Jarque-Bera (JB):                2.087
# Skew:                          -0.292   Prob(JB):                        0.352
# Kurtosis:                       2.212   Cond. No.                         155.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# HMLB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     5.734
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0204
# Time:                        01:56:38   Log-Likelihood:                -65.711
# No. Observations:                  52   AIC:                             135.4
# Df Residuals:                      50   BIC:                             139.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3256      0.316     10.514      0.000       2.690       3.961
# Blinking       0.0130      0.005      2.395      0.020       0.002       0.024
# ==============================================================================
# Omnibus:                        0.844   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.656   Jarque-Bera (JB):                0.914
# Skew:                          -0.271   Prob(JB):                        0.633
# Kurtosis:                       2.641   Cond. No.                         153.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# LMHB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     4.634
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0362
# Time:                        01:56:38   Log-Likelihood:                -62.135
# No. Observations:                  52   AIC:                             128.3
# Df Residuals:                      50   BIC:                             132.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.1696      0.301     10.542      0.000       2.566       3.774
# Blinking       0.0109      0.005      2.153      0.036       0.001       0.021
# ==============================================================================
# Omnibus:                        2.671   Durbin-Watson:                   1.533
# Prob(Omnibus):                  0.263   Jarque-Bera (JB):                2.550
# Skew:                          -0.488   Prob(JB):                        0.279
# Kurtosis:                       2.526   Cond. No.                         158.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# LMLB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          DynamicRating   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     6.225
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0159
# Time:                        01:56:38   Log-Likelihood:                -60.531
# No. Observations:                  52   AIC:                             125.1
# Df Residuals:                      50   BIC:                             129.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2039      0.282     11.357      0.000       2.637       3.770
# Blinking       0.0121      0.005      2.495      0.016       0.002       0.022
# ==============================================================================
# Omnibus:                        1.131   Durbin-Watson:                   1.712
# Prob(Omnibus):                  0.568   Jarque-Bera (JB):                1.145
# Skew:                          -0.251   Prob(JB):                        0.564
# Kurtosis:                       2.475   Cond. No.                         150.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================

# %%
# SSQ_LR 

for item_ind, item in enumerate(items) : 

    names = list(avg_data.keys())
    names.append(item)

    #block_df = pd.DataFrame(np.concatenate([block_arr.mean(axis=1), ssq_arr[item_ind].mean(axis=0).reshape(-1,1)], axis=1 ), columns=names)
    block_df = pd.DataFrame(np.concatenate([avg_arr, ssq_arr[item_ind].mean(axis=1).reshape(-1,1)], axis=1 ), columns=names)
    #block_df.to_csv(f"./{items[item_ind]}.csv")

    # block_df.apply(min_max_scaler)
    m = ols(f"{item} ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil", data=block_df).fit()
    #m = ols(f"{item} ~ Blinking", data=block_df).fit()


    if  m.f_pvalue < 0.05  : # np.sqrt(m.rsquared) >= 0.4 and
        print(f"[{items[item_ind]}]")
        #print(f"R vlaue : {np.sqrt(m.rsquared):.4f}")
        #print(f"R2 vlaue : {m.rsquared:.4f}")
        #print(f"ANOVA p-value : {m.f_pvalue:.3f}")
        print(m.summary())
        print("="*100)
        print( "\n")
# Out:
# [Dry_Eyed]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Dry_Eyed   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     2.691
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0171
# Time:                        02:19:08   Log-Likelihood:                -80.611
# No. Observations:                  52   AIC:                             179.2
# Df Residuals:                      43   BIC:                             196.8
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -22.8268     13.469     -1.695      0.097     -49.990       4.337
# Blinking              0.0332      0.011      3.016      0.004       0.011       0.055
# Fixation_Duration     0.0271      0.015      1.758      0.086      -0.004       0.058
# Fixation_Num          0.0389      0.020      1.899      0.064      -0.002       0.080
# Saccade_Duration      0.0256      0.024      1.064      0.293      -0.023       0.074
# left_iris             0.8734      0.626      1.395      0.170      -0.389       2.136
# right_iris           -0.0867      0.800     -0.108      0.914      -1.701       1.527
# left_pupil            1.0930      1.044      1.047      0.301      -1.013       3.199
# right_pupil          -1.1707      1.154     -1.014      0.316      -3.499       1.157
# ==============================================================================
# Omnibus:                        0.961   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.619   Jarque-Bera (JB):                0.747
# Skew:                          -0.291   Prob(JB):                        0.688
# Kurtosis:                       2.922   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
# [Eyestrain]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Eyestrain   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     2.287
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0388
# Time:                        02:19:09   Log-Likelihood:                -87.191
# No. Observations:                  52   AIC:                             192.4
# Df Residuals:                      43   BIC:                             209.9
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -28.3604     15.286     -1.855      0.070     -59.188       2.468
# Blinking              0.0272      0.012      2.181      0.035       0.002       0.052
# Fixation_Duration     0.0348      0.017      1.990      0.053      -0.000       0.070
# Fixation_Num          0.0445      0.023      1.914      0.062      -0.002       0.091
# Saccade_Duration      0.0548      0.027      2.007      0.051      -0.000       0.110
# left_iris             1.5284      0.711      2.151      0.037       0.095       2.962
# right_iris           -0.6957      0.908     -0.766      0.448      -2.527       1.136
# left_pupil            2.3521      1.185      1.985      0.054      -0.038       4.742
# right_pupil          -2.4259      1.310     -1.852      0.071      -5.068       0.216
# ==============================================================================
# Omnibus:                        1.445   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.486   Jarque-Bera (JB):                1.072
# Skew:                           0.009   Prob(JB):                        0.585
# Kurtosis:                       2.297   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
# [Eye_Ache]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Eye_Ache   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     2.802
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0137
# Time:                        02:19:09   Log-Likelihood:                -81.090
# No. Observations:                  52   AIC:                             180.2
# Df Residuals:                      43   BIC:                             197.7
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -26.2635     13.594     -1.932      0.060     -53.679       1.152
# Blinking              0.0361      0.011      3.255      0.002       0.014       0.059
# Fixation_Duration     0.0311      0.016      2.003      0.051      -0.000       0.062
# Fixation_Num          0.0334      0.021      1.617      0.113      -0.008       0.075
# Saccade_Duration      0.0616      0.024      2.538      0.015       0.013       0.111
# left_iris             0.9998      0.632      1.582      0.121      -0.275       2.274
# right_iris           -0.0970      0.808     -0.120      0.905      -1.726       1.532
# left_pupil            0.9020      1.054      0.856      0.397      -1.223       3.027
# right_pupil          -0.6689      1.165     -0.574      0.569      -3.018       1.681
# ==============================================================================
# Omnibus:                        0.018   Durbin-Watson:                   1.670
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.183
# Skew:                           0.008   Prob(JB):                        0.912
# Kurtosis:                       2.710   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
# [Heavy_Eyes]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Heavy_Eyes   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     2.816
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0133
# Time:                        02:19:09   Log-Likelihood:                -85.476
# No. Observations:                  52   AIC:                             189.0
# Df Residuals:                      43   BIC:                             206.5
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -37.4987     14.790     -2.535      0.015     -67.326      -7.671
# Blinking              0.0335      0.012      2.772      0.008       0.009       0.058
# Fixation_Duration     0.0408      0.017      2.414      0.020       0.007       0.075
# Fixation_Num          0.0516      0.022      2.292      0.027       0.006       0.097
# Saccade_Duration      0.0713      0.026      2.701      0.010       0.018       0.125
# left_iris             1.2182      0.688      1.772      0.084      -0.168       2.605
# right_iris            0.5307      0.879      0.604      0.549      -1.242       2.303
# left_pupil            1.2707      1.146      1.108      0.274      -1.041       3.583
# right_pupil          -1.2802      1.268     -1.010      0.318      -3.836       1.276
# ==============================================================================
# Omnibus:                        2.340   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.310   Jarque-Bera (JB):                1.457
# Skew:                          -0.118   Prob(JB):                        0.483
# Kurtosis:                       2.214   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
# [Warm_Eyes]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Warm_Eyes   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     2.304
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0375
# Time:                        02:19:09   Log-Likelihood:                -81.555
# No. Observations:                  52   AIC:                             181.1
# Df Residuals:                      43   BIC:                             198.7
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -19.5372     13.716     -1.424      0.162     -47.199       8.124
# Blinking              0.0304      0.011      2.712      0.010       0.008       0.053
# Fixation_Duration     0.0232      0.016      1.479      0.147      -0.008       0.055
# Fixation_Num          0.0262      0.021      1.254      0.217      -0.016       0.068
# Saccade_Duration      0.0247      0.024      1.007      0.320      -0.025       0.074
# left_iris             1.3414      0.638      2.104      0.041       0.056       2.627
# right_iris           -0.2832      0.815     -0.347      0.730      -1.927       1.360
# left_pupil            1.0884      1.063      1.024      0.312      -1.056       3.233
# right_pupil          -1.1782      1.175     -1.002      0.322      -3.549       1.192
# ==============================================================================
# Omnibus:                        0.565   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.754   Jarque-Bera (JB):                0.270
# Skew:                           0.175   Prob(JB):                        0.874
# Kurtosis:                       3.046   Cond. No.                     3.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================

# %%
# SSQ_LR 

for item_ind, item in enumerate(items) : 

    names = list(avg_data.keys())
    names.append(item)

    #block_df = pd.DataFrame(np.concatenate([block_arr.mean(axis=1), ssq_arr[item_ind].mean(axis=0).reshape(-1,1)], axis=1 ), columns=names)
    block_df = pd.DataFrame(np.concatenate([avg_arr, ssq_arr[item_ind].mean(axis=1).reshape(-1,1)], axis=1 ), columns=names)
    #block_df.to_csv(f"./{items[item_ind]}.csv")

    # block_df.apply(min_max_scaler)
    #m = ols(f"{item} ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil", data=block_df).fit()
    m = ols(f"{item} ~ Blinking", data=block_df).fit()


    if  m.f_pvalue < 0.05  : # np.sqrt(m.rsquared) >= 0.4 and
        print(f"[{items[item_ind]}]")
        #print(f"R vlaue : {np.sqrt(m.rsquared):.4f}")
        #print(f"R2 vlaue : {m.rsquared:.4f}")
        #print(f"ANOVA p-value : {m.f_pvalue:.3f}")
        print(m.summary())
        print("="*100)
        print( "\n")
# Out:
# [Bleary]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Bleary   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     5.042
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0292
# Time:                        14:29:45   Log-Likelihood:                -82.534
# No. Observations:                  52   AIC:                             169.1
# Df Residuals:                      50   BIC:                             173.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9772      0.445      4.440      0.000       1.083       2.872
# Blinking       0.0170      0.008      2.245      0.029       0.002       0.032
# ==============================================================================
# Omnibus:                        3.877   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                2.669
# Skew:                           0.383   Prob(JB):                        0.263
# Kurtosis:                       2.198   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Dry_Eyed]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Dry_Eyed   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     13.45
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):           0.000594
# Time:                        14:29:45   Log-Likelihood:                -84.970
# No. Observations:                  52   AIC:                             173.9
# Df Residuals:                      50   BIC:                             177.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6930      0.467      5.771      0.000       1.756       3.630
# Blinking       0.0291      0.008      3.667      0.001       0.013       0.045
# ==============================================================================
# Omnibus:                        0.916   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.633   Jarque-Bera (JB):                0.842
# Skew:                           0.005   Prob(JB):                        0.656
# Kurtosis:                       2.377   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Eyestrain]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Eyestrain   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     5.303
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0255
# Time:                        14:29:45   Log-Likelihood:                -93.788
# No. Observations:                  52   AIC:                             191.6
# Df Residuals:                      50   BIC:                             195.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6374      0.553      4.770      0.000       1.527       3.748
# Blinking       0.0217      0.009      2.303      0.025       0.003       0.041
# ==============================================================================
# Omnibus:                        9.247   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                2.823
# Skew:                           0.108   Prob(JB):                        0.244
# Kurtosis:                       1.879   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Gritty]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Gritty   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     8.331
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):            0.00574
# Time:                        14:29:45   Log-Likelihood:                -88.486
# No. Observations:                  52   AIC:                             181.0
# Df Residuals:                      50   BIC:                             184.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1885      0.499      2.380      0.021       0.186       2.191
# Blinking       0.0245      0.008      2.886      0.006       0.007       0.042
# ==============================================================================
# Omnibus:                        2.633   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.324
# Skew:                           0.514   Prob(JB):                        0.313
# Kurtosis:                       2.866   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Eye_Ache]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Eye_Ache   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     9.980
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):            0.00268
# Time:                        14:29:45   Log-Likelihood:                -87.266
# No. Observations:                  52   AIC:                             178.5
# Df Residuals:                      50   BIC:                             182.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9183      0.488      3.933      0.000       0.939       2.898
# Blinking       0.0262      0.008      3.159      0.003       0.010       0.043
# ==============================================================================
# Omnibus:                        7.927   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                2.557
# Skew:                           0.025   Prob(JB):                        0.278
# Kurtosis:                       1.915   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Sting]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sting   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     5.079
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0286
# Time:                        14:29:45   Log-Likelihood:                -83.947
# No. Observations:                  52   AIC:                             171.9
# Df Residuals:                      50   BIC:                             175.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8088      0.458      8.324      0.000       2.890       4.728
# Blinking       0.0175      0.008      2.254      0.029       0.002       0.033
# ==============================================================================
# Omnibus:                        4.309   Durbin-Watson:                   1.513
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                3.681
# Skew:                          -0.650   Prob(JB):                        0.159
# Kurtosis:                       3.091   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Heavy_Eyes]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Heavy_Eyes   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     5.408
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0241
# Time:                        14:29:45   Log-Likelihood:                -93.758
# No. Observations:                  52   AIC:                             191.5
# Df Residuals:                      50   BIC:                             195.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0784      0.553      3.761      0.000       0.969       3.188
# Blinking       0.0219      0.009      2.325      0.024       0.003       0.041
# ==============================================================================
# Omnibus:                        8.251   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                3.167
# Skew:                           0.283   Prob(JB):                        0.205
# Kurtosis:                       1.931   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Warm_Eyes]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Warm_Eyes   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     6.057
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0173
# Time:                        14:29:45   Log-Likelihood:                -87.859
# No. Observations:                  52   AIC:                             179.7
# Df Residuals:                      50   BIC:                             183.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5864      0.493      3.216      0.002       0.596       2.577
# Blinking       0.0207      0.008      2.461      0.017       0.004       0.038
# ==============================================================================
# Omnibus:                        3.411   Durbin-Watson:                   2.330
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                2.412
# Skew:                           0.357   Prob(JB):                        0.299
# Kurtosis:                       2.223   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Stiff_shoulder]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Stiff_shoulder   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     8.910
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):            0.00438
# Time:                        14:29:45   Log-Likelihood:                -90.023
# No. Observations:                  52   AIC:                             184.0
# Df Residuals:                      50   BIC:                             187.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2264      0.514      2.385      0.021       0.193       2.259
# Blinking       0.0261      0.009      2.985      0.004       0.009       0.044
# ==============================================================================
# Omnibus:                        4.795   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.625
# Skew:                           0.684   Prob(JB):                       0.0990
# Kurtosis:                       2.486   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Sleepy]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Sleepy   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     5.135
# Date:                Wed, 15 Nov 2023   Prob (F-statistic):             0.0278
# Time:                        14:29:45   Log-Likelihood:                -84.074
# No. Observations:                  52   AIC:                             172.1
# Df Residuals:                      50   BIC:                             176.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2724      0.459      4.954      0.000       1.351       3.194
# Blinking       0.0177      0.008      2.266      0.028       0.002       0.033
# ==============================================================================
# Omnibus:                        1.819   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.403   Jarque-Bera (JB):                1.275
# Skew:                           0.115   Prob(JB):                        0.529
# Kurtosis:                       2.268   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
#
#
# [Far_vision_difficulty]
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Far_vision_difficulty   R-squared:                       0.089
# Model:                               OLS   Adj. R-squared:                  0.070
# Method:                    Least Squares   F-statistic:                     4.865
# Date:                   Wed, 15 Nov 2023   Prob (F-statistic):             0.0320
# Time:                           14:29:45   Log-Likelihood:                -79.317
# No. Observations:                     52   AIC:                             162.6
# Df Residuals:                         50   BIC:                             166.5
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0626      0.419      2.539      0.014       0.222       1.903
# Blinking       0.0157      0.007      2.206      0.032       0.001       0.030
# ==============================================================================
# Omnibus:                        6.277   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                6.302
# Skew:                           0.844   Prob(JB):                       0.0428
# Kurtosis:                       2.763   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================

# %%
# Blokc별 SSQ LR

Blocks = ['HMHB', 'HMLB', "LMHB", "LMLB"]

# items = ['Bleary' , 'Dry_Eyed' , 'Eyestrain', 'Gritty', 'Eye_Ache', 'Sting', \
#         'Heavy_Eyes', 'Hazy', 'Warm_Eyes', 'Flickering', 'Watery_Eyes', 'Feeling_heavy_in_the_head', 'Feel_heavy', \
#         'Difficulty_concentrating', 'Dizzy', 'Stiff_shoulder', 'Stiff_neck', 'Sleepy', 'Vomiiting', 'Vertigo', 'Nausea', \
#         'Difficulty_focussing', 'Double_vision', 'Near_vision_difficulty', \
#         'Far_vision_difficulty', 'Pain_in_the_temple', 'Pain_in_the_middle_of_the_head', 'Pain_in_the_back_of_the_head' ]

#items = ['Dry_Eyed', 'Eyestrain', 'Eye_Ache', 'Heavy_Eyes', 'Flickering']

ssq_lr_dict = { }

for item_ind, item in enumerate(items) : 

    names = list(avg_data.keys())
    names.append(item)
    item_r = []

    for ind, value in enumerate(block_arr):        
        block_df = pd.DataFrame(np.concatenate([value, ssq_arr[item_ind][:,ind].reshape(-1,1)], axis=1 ), columns=names)
        #block_df.to_csv(f"./{items[item_ind]} - {Blocks[ind]}.csv")
        # block_df.apply(min_max_scaler)
        m = ols(f"{item} ~ Blinking + Fixation_Duration  + Fixation_Num + Saccade_Duration  + left_iris + right_iris + left_pupil +right_pupil", data=block_df).fit()
        print(f"{items[item_ind]} - {Blocks[ind]}")
        print(f"R vlaue : {np.sqrt(m.rsquared):.4f}")
        print(f"R2 vlaue : {m.rsquared:.4f}")
        print(f"ANOVA p-value : {m.f_pvalue:.3f}")
        #print(m.summary())
        print("="*100)
        print( "\n")

        item_r.append(np.sqrt(m.rsquared).round(3))

    ssq_lr_dict[item] = item_r
# Out:
# Bleary - HMHB
# R vlaue : 0.2991
# R2 vlaue : 0.0895
# ANOVA p-value : 0.829
# ====================================================================================================
#
#
# Bleary - HMLB
# R vlaue : 0.3990
# R2 vlaue : 0.1592
# ANOVA p-value : 0.438
# ====================================================================================================
#
#
# Bleary - LMHB
# R vlaue : 0.3153
# R2 vlaue : 0.0994
# ANOVA p-value : 0.778
# ====================================================================================================
#
#
# Bleary - LMLB
# R vlaue : 0.4083
# R2 vlaue : 0.1667
# ANOVA p-value : 0.398
# ====================================================================================================
#
#
# Dry_Eyed - HMHB
# R vlaue : 0.5648
# R2 vlaue : 0.3190
# ANOVA p-value : 0.024
# ====================================================================================================
#
#
# Dry_Eyed - HMLB
# R vlaue : 0.4945
# R2 vlaue : 0.2446
# ANOVA p-value : 0.117
# ====================================================================================================
#
#
# Dry_Eyed - LMHB
# R vlaue : 0.4854
# R2 vlaue : 0.2356
# ANOVA p-value : 0.137
# ====================================================================================================
#
#
# Dry_Eyed - LMLB
# R vlaue : 0.4992
# R2 vlaue : 0.2492
# ANOVA p-value : 0.107
# ====================================================================================================
#
#
# Eyestrain - HMHB
# R vlaue : 0.4662
# R2 vlaue : 0.2174
# ANOVA p-value : 0.188
# ====================================================================================================
#
#
# Eyestrain - HMLB
# R vlaue : 0.5137
# R2 vlaue : 0.2639
# ANOVA p-value : 0.080
# ====================================================================================================
#
#
# Eyestrain - LMHB
# R vlaue : 0.4355
# R2 vlaue : 0.1896
# ANOVA p-value : 0.291
# ====================================================================================================
#
#
# Eyestrain - LMLB
# R vlaue : 0.6226
# R2 vlaue : 0.3876
# ANOVA p-value : 0.004
# ====================================================================================================
#
#
# Gritty - HMHB
# R vlaue : 0.5229
# R2 vlaue : 0.2734
# ANOVA p-value : 0.066
# ====================================================================================================
#
#
# Gritty - HMLB
# R vlaue : 0.4907
# R2 vlaue : 0.2408
# ANOVA p-value : 0.125
# ====================================================================================================
#
#
# Gritty - LMHB
# R vlaue : 0.5267
# R2 vlaue : 0.2774
# ANOVA p-value : 0.061
# ====================================================================================================
#
#
# Gritty - LMLB
# R vlaue : 0.4898
# R2 vlaue : 0.2399
# ANOVA p-value : 0.127
# ====================================================================================================
#
#
# Eye_Ache - HMHB
# R vlaue : 0.5277
# R2 vlaue : 0.2785
# ANOVA p-value : 0.060
# ====================================================================================================
#
#
# Eye_Ache - HMLB
# R vlaue : 0.5183
# R2 vlaue : 0.2687
# ANOVA p-value : 0.073
# ====================================================================================================
#
#
# Eye_Ache - LMHB
# R vlaue : 0.4786
# R2 vlaue : 0.2291
# ANOVA p-value : 0.154
# ====================================================================================================
#
#
# Eye_Ache - LMLB
# R vlaue : 0.6188
# R2 vlaue : 0.3830
# ANOVA p-value : 0.005
# ====================================================================================================
#
#
# Sting - HMHB
# R vlaue : 0.3537
# R2 vlaue : 0.1251
# ANOVA p-value : 0.632
# ====================================================================================================
#
#
# Sting - HMLB
# R vlaue : 0.3974
# R2 vlaue : 0.1579
# ANOVA p-value : 0.444
# ====================================================================================================
#
#
# Sting - LMHB
# R vlaue : 0.4190
# R2 vlaue : 0.1756
# ANOVA p-value : 0.354
# ====================================================================================================
#
#
# Sting - LMLB
# R vlaue : 0.4460
# R2 vlaue : 0.1989
# ANOVA p-value : 0.253
# ====================================================================================================
#
#
# Heavy_Eyes - HMHB
# R vlaue : 0.5070
# R2 vlaue : 0.2571
# ANOVA p-value : 0.092
# ====================================================================================================
#
#
# Heavy_Eyes - HMLB
# R vlaue : 0.4456
# R2 vlaue : 0.1986
# ANOVA p-value : 0.254
# ====================================================================================================
#
#
# Heavy_Eyes - LMHB
# R vlaue : 0.5527
# R2 vlaue : 0.3055
# ANOVA p-value : 0.033
# ====================================================================================================
#
#
# Heavy_Eyes - LMLB
# R vlaue : 0.6031
# R2 vlaue : 0.3637
# ANOVA p-value : 0.008
# ====================================================================================================
#
#
# Hazy - HMHB
# R vlaue : 0.3449
# R2 vlaue : 0.1190
# ANOVA p-value : 0.668
# ====================================================================================================
#
#
# Hazy - HMLB
# R vlaue : 0.4352
# R2 vlaue : 0.1894
# ANOVA p-value : 0.291
# ====================================================================================================
#
#
# Hazy - LMHB
# R vlaue : 0.3807
# R2 vlaue : 0.1450
# ANOVA p-value : 0.516
# ====================================================================================================
#
#
# Hazy - LMLB
# R vlaue : 0.5135
# R2 vlaue : 0.2637
# ANOVA p-value : 0.081
# ====================================================================================================
#
#
# Warm_Eyes - HMHB
# R vlaue : 0.5205
# R2 vlaue : 0.2709
# ANOVA p-value : 0.070
# ====================================================================================================
#
#
# Warm_Eyes - HMLB
# R vlaue : 0.5359
# R2 vlaue : 0.2872
# ANOVA p-value : 0.050
# ====================================================================================================
#
#
# Warm_Eyes - LMHB
# R vlaue : 0.4087
# R2 vlaue : 0.1670
# ANOVA p-value : 0.396
# ====================================================================================================
#
#
# Warm_Eyes - LMLB
# R vlaue : 0.5414
# R2 vlaue : 0.2931
# ANOVA p-value : 0.044
# ====================================================================================================
#
#
# Flickering - HMHB
# R vlaue : 0.4837
# R2 vlaue : 0.2340
# ANOVA p-value : 0.141
# ====================================================================================================
#
#
# Flickering - HMLB
# R vlaue : 0.5041
# R2 vlaue : 0.2541
# ANOVA p-value : 0.097
# ====================================================================================================
#
#
# Flickering - LMHB
# R vlaue : 0.3506
# R2 vlaue : 0.1229
# ANOVA p-value : 0.645
# ====================================================================================================
#
#
# Flickering - LMLB
# R vlaue : 0.4406
# R2 vlaue : 0.1941
# ANOVA p-value : 0.272
# ====================================================================================================
#
#
# Watery_Eyes - HMHB
# R vlaue : 0.4881
# R2 vlaue : 0.2383
# ANOVA p-value : 0.131
# ====================================================================================================
#
#
# Watery_Eyes - HMLB
# R vlaue : 0.2817
# R2 vlaue : 0.0794
# ANOVA p-value : 0.875
# ====================================================================================================
#
#
# Watery_Eyes - LMHB
# R vlaue : 0.3611
# R2 vlaue : 0.1304
# ANOVA p-value : 0.601
# ====================================================================================================
#
#
# Watery_Eyes - LMLB
# R vlaue : 0.4591
# R2 vlaue : 0.2108
# ANOVA p-value : 0.210
# ====================================================================================================
#
#
# Feeling_heavy_in_the_head - HMHB
# R vlaue : 0.3168
# R2 vlaue : 0.1004
# ANOVA p-value : 0.773
# ====================================================================================================
#
#
# Feeling_heavy_in_the_head - HMLB
# R vlaue : 0.4322
# R2 vlaue : 0.1868
# ANOVA p-value : 0.303
# ====================================================================================================
#
#
# Feeling_heavy_in_the_head - LMHB
# R vlaue : 0.4177
# R2 vlaue : 0.1745
# ANOVA p-value : 0.359
# ====================================================================================================
#
#
# Feeling_heavy_in_the_head - LMLB
# R vlaue : 0.4200
# R2 vlaue : 0.1764
# ANOVA p-value : 0.350
# ====================================================================================================
#
#
# Feel_heavy - HMHB
# R vlaue : 0.3748
# R2 vlaue : 0.1404
# ANOVA p-value : 0.542
# ====================================================================================================
#
#
# Feel_heavy - HMLB
# R vlaue : 0.4633
# R2 vlaue : 0.2147
# ANOVA p-value : 0.197
# ====================================================================================================
#
#
# Feel_heavy - LMHB
# R vlaue : 0.3594
# R2 vlaue : 0.1291
# ANOVA p-value : 0.608
# ====================================================================================================
#
#
# Feel_heavy - LMLB
# R vlaue : 0.4797
# R2 vlaue : 0.2301
# ANOVA p-value : 0.151
# ====================================================================================================
#
#
# Difficulty_concentrating - HMHB
# R vlaue : 0.4026
# R2 vlaue : 0.1621
# ANOVA p-value : 0.422
# ====================================================================================================
#
#
# Difficulty_concentrating - HMLB
# R vlaue : 0.4727
# R2 vlaue : 0.2235
# ANOVA p-value : 0.170
# ====================================================================================================
#
#
# Difficulty_concentrating - LMHB
# R vlaue : 0.3390
# R2 vlaue : 0.1149
# ANOVA p-value : 0.691
# ====================================================================================================
#
#
# Difficulty_concentrating - LMLB
# R vlaue : 0.5050
# R2 vlaue : 0.2550
# ANOVA p-value : 0.096
# ====================================================================================================
#
#
# Dizzy - HMHB
# R vlaue : 0.3293
# R2 vlaue : 0.1084
# ANOVA p-value : 0.728
# ====================================================================================================
#
#
# Dizzy - HMLB
# R vlaue : 0.3693
# R2 vlaue : 0.1364
# ANOVA p-value : 0.566
# ====================================================================================================
#
#
# Dizzy - LMHB
# R vlaue : 0.4723
# R2 vlaue : 0.2230
# ANOVA p-value : 0.171
# ====================================================================================================
#
#
# Dizzy - LMLB
# R vlaue : 0.3560
# R2 vlaue : 0.1268
# ANOVA p-value : 0.622
# ====================================================================================================
#
#
# Stiff_shoulder - HMHB
# R vlaue : 0.5279
# R2 vlaue : 0.2787
# ANOVA p-value : 0.059
# ====================================================================================================
#
#
# Stiff_shoulder - HMLB
# R vlaue : 0.4570
# R2 vlaue : 0.2089
# ANOVA p-value : 0.216
# ====================================================================================================
#
#
# Stiff_shoulder - LMHB
# R vlaue : 0.4088
# R2 vlaue : 0.1671
# ANOVA p-value : 0.396
# ====================================================================================================
#
#
# Stiff_shoulder - LMLB
# R vlaue : 0.3717
# R2 vlaue : 0.1381
# ANOVA p-value : 0.556
# ====================================================================================================
#
#
# Stiff_neck - HMHB
# R vlaue : 0.3808
# R2 vlaue : 0.1450
# ANOVA p-value : 0.516
# ====================================================================================================
#
#
# Stiff_neck - HMLB
# R vlaue : 0.2982
# R2 vlaue : 0.0889
# ANOVA p-value : 0.831
# ====================================================================================================
#
#
# Stiff_neck - LMHB
# R vlaue : 0.3392
# R2 vlaue : 0.1150
# ANOVA p-value : 0.691
# ====================================================================================================
#
#
# Stiff_neck - LMLB
# R vlaue : 0.3856
# R2 vlaue : 0.1487
# ANOVA p-value : 0.495
# ====================================================================================================
#
#
# Sleepy - HMHB
# R vlaue : 0.2947
# R2 vlaue : 0.0869
# ANOVA p-value : 0.841
# ====================================================================================================
#
#
# Sleepy - HMLB
# R vlaue : 0.4697
# R2 vlaue : 0.2206
# ANOVA p-value : 0.178
# ====================================================================================================
#
#
# Sleepy - LMHB
# R vlaue : 0.4631
# R2 vlaue : 0.2144
# ANOVA p-value : 0.198
# ====================================================================================================
#
#
# Sleepy - LMLB
# R vlaue : 0.4422
# R2 vlaue : 0.1955
# ANOVA p-value : 0.266
# ====================================================================================================
#
#
# Vomiiting - HMHB
# R vlaue : 0.4624
# R2 vlaue : 0.2138
# ANOVA p-value : 0.199
# ====================================================================================================
#
#
# Vomiiting - HMLB
# R vlaue : 0.2953
# R2 vlaue : 0.0872
# ANOVA p-value : 0.840
# ====================================================================================================
#
#
# Vomiiting - LMHB
# R vlaue : 0.2957
# R2 vlaue : 0.0875
# ANOVA p-value : 0.838
# ====================================================================================================
#
#
# Vomiiting - LMLB
# R vlaue : 0.4006
# R2 vlaue : 0.1605
# ANOVA p-value : 0.430
# ====================================================================================================
#
#
# Vertigo - HMHB
# R vlaue : 0.4341
# R2 vlaue : 0.1884
# ANOVA p-value : 0.296
# ====================================================================================================
#
#
# Vertigo - HMLB
# R vlaue : 0.4215
# R2 vlaue : 0.1776
# ANOVA p-value : 0.344
# ====================================================================================================
#
#
# Vertigo - LMHB
# R vlaue : 0.3178
# R2 vlaue : 0.1010
# ANOVA p-value : 0.769
# ====================================================================================================
#
#
# Vertigo - LMLB
# R vlaue : 0.3175
# R2 vlaue : 0.1008
# ANOVA p-value : 0.770
# ====================================================================================================
#
#
# Nausea - HMHB
# R vlaue : 0.4626
# R2 vlaue : 0.2140
# ANOVA p-value : 0.199
# ====================================================================================================
#
#
# Nausea - HMLB
# R vlaue : 0.3706
# R2 vlaue : 0.1374
# ANOVA p-value : 0.560
# ====================================================================================================
#
#
# Nausea - LMHB
# R vlaue : 0.3514
# R2 vlaue : 0.1235
# ANOVA p-value : 0.642
# ====================================================================================================
#
#
# Nausea - LMLB
# R vlaue : 0.3868
# R2 vlaue : 0.1496
# ANOVA p-value : 0.490
# ====================================================================================================
#
#
# Difficulty_focussing - HMHB
# R vlaue : 0.4046
# R2 vlaue : 0.1637
# ANOVA p-value : 0.414
# ====================================================================================================
#
#
# Difficulty_focussing - HMLB
# R vlaue : 0.4615
# R2 vlaue : 0.2130
# ANOVA p-value : 0.202
# ====================================================================================================
#
#
# Difficulty_focussing - LMHB
# R vlaue : 0.3459
# R2 vlaue : 0.1197
# ANOVA p-value : 0.664
# ====================================================================================================
#
#
# Difficulty_focussing - LMLB
# R vlaue : 0.4086
# R2 vlaue : 0.1669
# ANOVA p-value : 0.397
# ====================================================================================================
#
#
# Double_vision - HMHB
# R vlaue : 0.3860
# R2 vlaue : 0.1490
# ANOVA p-value : 0.493
# ====================================================================================================
#
#
# Double_vision - HMLB
# R vlaue : 0.4423
# R2 vlaue : 0.1957
# ANOVA p-value : 0.266
# ====================================================================================================
#
#
# Double_vision - LMHB
# R vlaue : 0.3245
# R2 vlaue : 0.1053
# ANOVA p-value : 0.746
# ====================================================================================================
#
#
# Double_vision - LMLB
# R vlaue : 0.3667
# R2 vlaue : 0.1345
# ANOVA p-value : 0.577
# ====================================================================================================
#
#
# Near_vision_difficulty - HMHB
# R vlaue : 0.2639
# R2 vlaue : 0.0696
# ANOVA p-value : 0.913
# ====================================================================================================
#
#
# Near_vision_difficulty - HMLB
# R vlaue : 0.2839
# R2 vlaue : 0.0806
# ANOVA p-value : 0.870
# ====================================================================================================
#
#
# Near_vision_difficulty - LMHB
# R vlaue : 0.3200
# R2 vlaue : 0.1024
# ANOVA p-value : 0.762
# ====================================================================================================
#
#
# Near_vision_difficulty - LMLB
# R vlaue : 0.3202
# R2 vlaue : 0.1025
# ANOVA p-value : 0.761
# ====================================================================================================
#
#
# Far_vision_difficulty - HMHB
# R vlaue : 0.3471
# R2 vlaue : 0.1205
# ANOVA p-value : 0.659
# ====================================================================================================
#
#
# Far_vision_difficulty - HMLB
# R vlaue : 0.3889
# R2 vlaue : 0.1512
# ANOVA p-value : 0.481
# ====================================================================================================
#
#
# Far_vision_difficulty - LMHB
# R vlaue : 0.3406
# R2 vlaue : 0.1160
# ANOVA p-value : 0.685
# ====================================================================================================
#
#
# Far_vision_difficulty - LMLB
# R vlaue : 0.3996
# R2 vlaue : 0.1597
# ANOVA p-value : 0.435
# ====================================================================================================
#
#
# Pain_in_the_temple - HMHB
# R vlaue : 0.2578
# R2 vlaue : 0.0665
# ANOVA p-value : 0.924
# ====================================================================================================
#
#
# Pain_in_the_temple - HMLB
# R vlaue : 0.3616
# R2 vlaue : 0.1308
# ANOVA p-value : 0.599
# ====================================================================================================
#
#
# Pain_in_the_temple - LMHB
# R vlaue : 0.5192
# R2 vlaue : 0.2695
# ANOVA p-value : 0.072
# ====================================================================================================
#
#
# Pain_in_the_temple - LMLB
# R vlaue : 0.4669
# R2 vlaue : 0.2180
# ANOVA p-value : 0.186
# ====================================================================================================
#
#
# Pain_in_the_middle_of_the_head - HMHB
# R vlaue : 0.3405
# R2 vlaue : 0.1160
# ANOVA p-value : 0.685
# ====================================================================================================
#
#
# Pain_in_the_middle_of_the_head - HMLB
# R vlaue : 0.3973
# R2 vlaue : 0.1578
# ANOVA p-value : 0.445
# ====================================================================================================
#
#
# Pain_in_the_middle_of_the_head - LMHB
# R vlaue : 0.5055
# R2 vlaue : 0.2555
# ANOVA p-value : 0.095
# ====================================================================================================
#
#
# Pain_in_the_middle_of_the_head - LMLB
# R vlaue : 0.3837
# R2 vlaue : 0.1472
# ANOVA p-value : 0.503
# ====================================================================================================
#
#
# Pain_in_the_back_of_the_head - HMHB
# R vlaue : 0.2816
# R2 vlaue : 0.0793
# ANOVA p-value : 0.875
# ====================================================================================================
#
#
# Pain_in_the_back_of_the_head - HMLB
# R vlaue : 0.2607
# R2 vlaue : 0.0680
# ANOVA p-value : 0.919
# ====================================================================================================
#
#
# Pain_in_the_back_of_the_head - LMHB
# R vlaue : 0.4008
# R2 vlaue : 0.1607
# ANOVA p-value : 0.430
# ====================================================================================================
#
#
# Pain_in_the_back_of_the_head - LMLB
# R vlaue : 0.3423
# R2 vlaue : 0.1172
# ANOVA p-value : 0.678
# ====================================================================================================
